# %%
# %pip install pdfminer.six pandas
# Out:
# Requirement already satisfied: pdfminer.six in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (20250506)
# Requirement already satisfied: pandas in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (2.2.2)
# Requirement already satisfied: charset-normalizer>=2.0.0 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from pdfminer.six) (3.4.1)
# Requirement already satisfied: cryptography>=36.0.0 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from pdfminer.six) (45.0.4)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: cffi>=1.14 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from cryptography>=36.0.0->pdfminer.six) (1.17.1)
# Requirement already satisfied: six>=1.5 in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: pycparser in c:\users\asus\appdata\local\programs\python\python311\lib\site-packages (from cffi>=1.14->cryptography>=36.0.0->pdfminer.six) (2.22)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
import re
import csv
import logging
from datetime import datetime

# Define base directory
try:
    # For .py scripts
    BASE_DIR = os.path.dirname(os.path.abspath(__file__))
except NameError:
    # For Jupyter Notebooks or interactive sessions
    BASE_DIR = os.getcwd()

# Define paths
PATH_OUTPUT = os.path.join(BASE_DIR, 'data', 'raw')
path_csv = os.path.join(BASE_DIR, 'data', 'processed', 'cases.csv')
log_dir = os.path.join(BASE_DIR, 'logs')
log_path = os.path.join(log_dir, 'metadata_extraction.log')

# Ensure directories exist
os.makedirs(log_dir, exist_ok=True)
os.makedirs(os.path.dirname(path_csv), exist_ok=True)

# Initialize logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(message)s',
    handlers=[
        logging.FileHandler(log_path),
        logging.StreamHandler()
    ]
)
logging.info("Starting metadata extraction process at %s", datetime.now().strftime('%H:%M:%S %Z on %A, %B %d, %Y'))

# Map Indonesian month names to English
month_map = {
    'januari': 'January',
    'februari': 'February',
    'maret': 'March',
    'april': 'April',
    'mei': 'May',
    'juni': 'June',
    'juli': 'July',
    'agustus': 'August',
    'september': 'September',
    'oktober': 'October',
    'november': 'November',
    'desember': 'December'
}

def extract_metadata(text, file_name):
    metadata = {
        'case_id': file_name.replace('.txt', ''),
        'nomor_perkara': '',
        'tahun_putusan': '',
        'bulan_putusan': '',
        'tanggal_putusan': '',
        'jenis_perkara': '',
        'tingkat_pemeriksaan': '',
        'lembaga_peradilan': '',
        'hakim_ketua': '',
        'pasal': '',
        'ringkasan_fakta': '',
        'jumlah_kata_putusan': 0
    }

    # Helper function to clean and normalize extracted text
    def clean_name(text):
        if not text:
            return ''
        # Remove titles and prefixes like s h, m h, cla, ttd, etc.
        text = re.sub(r'\s*(s\s*h|m\s*h|cla|ccfa|cbc|ttd)\s*', ' ', text, flags=re.IGNORECASE).strip()
        # Normalize whitespace
        text = ' '.join(text.split())
        return text

    # Extract nomor_perkara (e.g., "nomor 1227 k pdt sus pailit 2024" or "nomor 10 pk pdt sus pailit 2025")
    match = re.search(r'nomor\s+(\d+\s+(?:pk|k)\s+pdt\s+sus\s+pailit\s+\d{4})', text, re.IGNORECASE)
    if match:
        metadata['nomor_perkara'] = match.group(1)
    else:
        logging.warning(f"No nomor_perkara found in {file_name}")
    logging.info(f"Extracted nomor_perkara: {metadata['nomor_perkara']} for {file_name}")

    # Extract tahun_putusan, bulan_putusan, tanggal_putusan
    date_patterns = [
        r'\w+\s+tanggal\s+(\d{1,2}\s+\w+\s+\d{4})',  # e.g., "12 agustus 2024"
        r'tanggal\s+(\d{1,2}\s+\w+\s+\d{4})',       # e.g., "tanggal 12 agustus 2024"
        r'(\d{1,2}\s+\w+\s+\d{4})',                 # e.g., "12 agustus 2024" standalone
    ]
    date_formats = [
        '%d %B %Y',  # e.g., "12 August 2024"
        '%d %b %Y',  # e.g., "12 Aug 2024"
        '%d %m %Y',  # e.g., "12 08 2024"
    ]

    date_found = False
    for pattern in date_patterns:
        match = re.search(pattern, text, re.IGNORECASE)
        if match:
            full_date = match.group(1)
            # Replace Indonesian month names with English
            for id_month, en_month in month_map.items():
                full_date = re.sub(rf'\b{id_month}\b', en_month, full_date, flags=re.IGNORECASE)
            for date_format in date_formats:
                try:
                    date_obj = datetime.strptime(full_date, date_format)
                    metadata['tahun_putusan'] = str(date_obj.year)
                    metadata['bulan_putusan'] = date_obj.strftime('%B')
                    metadata['tanggal_putusan'] = str(date_obj.day)  # Extract only the day
                    date_found = True
                    break
                except ValueError:
                    continue
            if date_found:
                break
            else:
                logging.warning(f"Failed to parse date '{full_date}' in {file_name} with formats {date_formats}")
        if date_found:
            break
    if not date_found:
        logging.warning(f"No valid date found in {file_name}. Sample text: {text[:200]}")

    # Extract jenis_perkara
    if 'kepailitan' in text.lower():
        metadata['jenis_perkara'] = 'Kepailitan'

    # Extract tingkat_pemeriksaan
    if 'peninjauan kembali' in text.lower():
        metadata['tingkat_pemeriksaan'] = 'Peninjauan Kembali'
    elif 'kasasi' in text.lower():
        metadata['tingkat_pemeriksaan'] = 'Kasasi'
    else:
        metadata['tingkat_pemeriksaan'] = 'Pertama'

    # Extract lembaga_peradilan
    if 'mahkamah agung' in text.lower():
        metadata['lembaga_peradilan'] = 'Mahkamah Agung'
    elif 'pengadilan negeri' in text.lower():
        metadata['lembaga_peradilan'] = 'Pengadilan Negeri'

    # Extract hakim_ketua
    match = re.search(r'ketua\s+majelis\s+([^\s][^,]+?)(?=\s+dan\s+[^\s].*?\s+hakim\s+hakim\s+anggota)', text, re.IGNORECASE)
    if match:
        metadata['hakim_ketua'] = clean_name(match.group(1))
    logging.warning(f"No hakim_ketua found in {file_name}") if not metadata['hakim_ketua'] else None

    # Extract pasal
    match = re.search(r'memperhatikan\s+undang\s+undang\s+nomor\s+(\d+\s+tahun\s+\d{4})', text, re.IGNORECASE)
    if match:
        metadata['pasal'] = match.group(1)

    # Extract ringkasan_fakta (formerly putusan)
    match = re.search(r'm\s+e\s+n\s+g\s+a\s+d\s+i\s+l\s+i\s+((?:\d+\s+)?[^\s].*?)(?=\s+demikian|\s+menimbang|\s*$)', text, re.IGNORECASE)
    if match:
        metadata['ringkasan_fakta'] = ' '.join(match.group(1).split())
    else:
        logging.warning(f"No ringkasan_fakta found in {file_name}. Sample text: {text[-200:]}")

    # Calculate jumlah_kata_putusan
    words = text.split()
    metadata['jumlah_kata_putusan'] = len(words)

    logging.info(f"Extracted metadata from {file_name}")
    return metadata

def save_to_csv(metadata_list):
    fieldnames = [
        'case_id', 'nomor_perkara', 'tahun_putusan', 'bulan_putusan', 'tanggal_putusan',
        'jenis_perkara', 'tingkat_pemeriksaan', 'lembaga_peradilan', 'hakim_ketua',
        'pasal', 'ringkasan_fakta', 'jumlah_kata_putusan'
    ]

    with open(path_csv, 'w', newline='', encoding='utf-8') as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()
        for metadata in metadata_list:
            writer.writerow(metadata)
    logging.info(f"Saved metadata to {path_csv}")

def process_text_files():
    metadata_list = []
    try:
        text_files = [f for f in os.listdir(PATH_OUTPUT) if f.endswith('.txt')]
        logging.info(f"Found {len(text_files)} text files to process in {PATH_OUTPUT}")
    except FileNotFoundError:
        logging.error(f"Directory {PATH_OUTPUT} does not exist")
        return

    for text_file in text_files:
        file_path = os.path.join(PATH_OUTPUT, text_file)
        try:
            with open(file_path, 'r', encoding='utf-8') as f:
                text = f.read().strip()
            metadata = extract_metadata(text, text_file)
            metadata_list.append(metadata)
            logging.info(f"Processed text file: {text_file}")
        except Exception as e:
            logging.error(f"Error processing {text_file}: {str(e)}")

    if metadata_list:
        save_to_csv(metadata_list)
        logging.info(f"Processed {len(metadata_list)} files and saved to {path_csv}")
    else:
        logging.warning("No files processed or no metadata extracted")

# Run the processor
if __name__ == "__main__":
    process_text_files()
# Out:
# 2025-06-22 20:08:38,092 - Starting metadata extraction process at 20:08:38  on Sunday, June 22, 2025
# 2025-06-22 20:08:38,094 - Found 60 text files to process in d:\AL FITRA\STUDI UMM\SEMESTER 6\TEORI\PENALARAN KOMPUTER\SOURCE CODE\PENALARAN KOMPUTER\COMPUTER_REASONING_CBR\CBR\data\raw
# 2025-06-22 20:08:38,095 - Extracted nomor_perkara: 10 pk pdt sus pailit 2025 for case_001.txt
# 2025-06-22 20:08:38,097 - Extracted metadata from case_001.txt
# 2025-06-22 20:08:38,099 - Processed text file: case_001.txt
# 2025-06-22 20:08:38,100 - Extracted nomor_perkara: 1178 k pdt sus pailit 2024 for case_002.txt
# 2025-06-22 20:08:38,104 - Extracted metadata from case_002.txt
# 2025-06-22 20:08:38,105 - Processed text file: case_002.txt
# 2025-06-22 20:08:38,107 - Extracted nomor_perkara: 11 pk pdt sus pailit 2025 for case_003.txt
# 2025-06-22 20:08:38,109 - Extracted metadata from case_003.txt
# 2025-06-22 20:08:38,110 - Processed text file: case_003.txt
# 2025-06-22 20:08:38,111 - Extracted nomor_perkara: 1227 k pdt sus pailit 2024 for case_004.txt
# 2025-06-22 20:08:38,113 - Extracted metadata from case_004.txt
# 2025-06-22 20:08:38,114 - Processed text file: case_004.txt
# 2025-06-22 20:08:38,115 - Extracted nomor_perkara: 123 k pdt sus pailit 2025 for case_005.txt
# 2025-06-22 20:08:38,117 - Extracted metadata from case_005.txt
# 2025-06-22 20:08:38,119 - Processed text file: case_005.txt
# 2025-06-22 20:08:38,120 - Extracted nomor_perkara: 12 pk pdt sus pailit 2025 for case_006.txt
# 2025-06-22 20:08:38,122 - Extracted metadata from case_006.txt
# 2025-06-22 20:08:38,123 - Processed text file: case_006.txt
# 2025-06-22 20:08:38,124 - Extracted nomor_perkara: 1318 k pdt sus pailit 2024 for case_007.txt
# 2025-06-22 20:08:38,126 - Extracted metadata from case_007.txt
# 2025-06-22 20:08:38,127 - Processed text file: case_007.txt
# 2025-06-22 20:08:38,129 - Extracted nomor_perkara: 1345 k pdt sus pailit 2024 for case_008.txt
# 2025-06-22 20:08:38,130 - Extracted metadata from case_008.txt
# 2025-06-22 20:08:38,131 - Processed text file: case_008.txt
# 2025-06-22 20:08:38,132 - Extracted nomor_perkara: 134 k pdt sus pailit 2025 for case_009.txt
# 2025-06-22 20:08:38,134 - Extracted metadata from case_009.txt
# 2025-06-22 20:08:38,135 - Processed text file: case_009.txt
# 2025-06-22 20:08:38,137 - Extracted nomor_perkara: 135 k pdt sus pailit 2025 for case_010.txt
# 2025-06-22 20:08:38,139 - Extracted metadata from case_010.txt
# 2025-06-22 20:08:38,140 - Processed text file: case_010.txt
# 2025-06-22 20:08:38,141 - Extracted nomor_perkara: 137 k pdt sus pailit 2025 for case_011.txt
# 2025-06-22 20:08:38,143 - Extracted metadata from case_011.txt
# 2025-06-22 20:08:38,144 - Processed text file: case_011.txt
# 2025-06-22 20:08:38,145 - Extracted nomor_perkara: 13 k pdt sus pailit 2025 for case_012.txt
# 2025-06-22 20:08:38,147 - Extracted metadata from case_012.txt
# 2025-06-22 20:08:38,148 - Processed text file: case_012.txt
# 2025-06-22 20:08:38,149 - Extracted nomor_perkara: 13 pk pdt sus pailit 2025 for case_013.txt
# 2025-06-22 20:08:38,151 - Extracted metadata from case_013.txt
# 2025-06-22 20:08:38,151 - Processed text file: case_013.txt
# 2025-06-22 20:08:38,152 - Extracted nomor_perkara: 15 pk pdt sus pailit 2025 for case_014.txt
# 2025-06-22 20:08:38,156 - Extracted metadata from case_014.txt
# 2025-06-22 20:08:38,157 - Processed text file: case_014.txt
# 2025-06-22 20:08:38,159 - No nomor_perkara found in case_015.txt
# 2025-06-22 20:08:38,160 - Extracted nomor_perkara:  for case_015.txt
# 2025-06-22 20:08:38,161 - Extracted metadata from case_015.txt
# 2025-06-22 20:08:38,163 - Processed text file: case_015.txt
# 2025-06-22 20:08:38,165 - Extracted nomor_perkara: 17 pk pdt sus pailit 2025 for case_016.txt
# 2025-06-22 20:08:38,167 - Extracted metadata from case_016.txt
# 2025-06-22 20:08:38,168 - Processed text file: case_016.txt
# 2025-06-22 20:08:38,171 - Extracted nomor_perkara: 185 k pdt sus pailit 2025 for case_017.txt
# 2025-06-22 20:08:38,173 - Extracted metadata from case_017.txt
# 2025-06-22 20:08:38,175 - Processed text file: case_017.txt
# 2025-06-22 20:08:38,177 - Extracted nomor_perkara: 187 k pdt sus pailit 2025 for case_018.txt
# 2025-06-22 20:08:38,180 - Extracted metadata from case_018.txt
# 2025-06-22 20:08:38,182 - Processed text file: case_018.txt
# 2025-06-22 20:08:38,184 - Extracted nomor_perkara: 203 k pdt sus pailit 2025 for case_019.txt
# 2025-06-22 20:08:38,185 - Extracted metadata from case_019.txt
# 2025-06-22 20:08:38,186 - Processed text file: case_019.txt
# 2025-06-22 20:08:38,187 - Extracted nomor_perkara: 204 k pdt sus pailit 2025 for case_020.txt
# 2025-06-22 20:08:38,191 - Extracted metadata from case_020.txt
# 2025-06-22 20:08:38,193 - Processed text file: case_020.txt
# 2025-06-22 20:08:38,196 - Extracted nomor_perkara: 24 k pdt sus pailit 2025 for case_021.txt
# 2025-06-22 20:08:38,204 - Extracted metadata from case_021.txt
# 2025-06-22 20:08:38,205 - Processed text file: case_021.txt
# 2025-06-22 20:08:38,206 - Extracted nomor_perkara: 260 k pdt sus pailit 2025 for case_022.txt
# 2025-06-22 20:08:38,208 - Extracted metadata from case_022.txt
# 2025-06-22 20:08:38,209 - Processed text file: case_022.txt
# 2025-06-22 20:08:38,211 - Extracted nomor_perkara: 261 k pdt sus pailit 2025 for case_023.txt
# 2025-06-22 20:08:38,212 - Extracted metadata from case_023.txt
# 2025-06-22 20:08:38,213 - Processed text file: case_023.txt
# 2025-06-22 20:08:38,216 - Extracted nomor_perkara: 265 k pdt sus pailit 2025 for case_024.txt
# 2025-06-22 20:08:38,217 - Extracted metadata from case_024.txt
# 2025-06-22 20:08:38,219 - Processed text file: case_024.txt
# 2025-06-22 20:08:38,220 - Extracted nomor_perkara: 277 k pdt sus pailit 2025 for case_025.txt
# 2025-06-22 20:08:38,221 - Extracted metadata from case_025.txt
# 2025-06-22 20:08:38,222 - Processed text file: case_025.txt
# 2025-06-22 20:08:38,225 - Extracted nomor_perkara: 281 k pdt sus pailit 2025 for case_026.txt
# 2025-06-22 20:08:38,228 - Extracted metadata from case_026.txt
# 2025-06-22 20:08:38,230 - Processed text file: case_026.txt
# 2025-06-22 20:08:38,231 - Extracted nomor_perkara: 297 k pdt sus pailit 2025 for case_027.txt
# 2025-06-22 20:08:38,235 - Extracted metadata from case_027.txt
# 2025-06-22 20:08:38,237 - Processed text file: case_027.txt
# 2025-06-22 20:08:38,238 - Extracted nomor_perkara: 305 k pdt sus pailit 2025 for case_028.txt
# 2025-06-22 20:08:38,240 - Extracted metadata from case_028.txt
# 2025-06-22 20:08:38,241 - Processed text file: case_028.txt
# 2025-06-22 20:08:38,242 - Extracted nomor_perkara: 307 k pdt sus pailit 2025 for case_029.txt
# 2025-06-22 20:08:38,245 - Extracted metadata from case_029.txt
# 2025-06-22 20:08:38,246 - Processed text file: case_029.txt
# 2025-06-22 20:08:38,248 - Extracted nomor_perkara: 308 k pdt sus pailit 2025 for case_030.txt
# 2025-06-22 20:08:38,250 - Extracted metadata from case_030.txt
# 2025-06-22 20:08:38,250 - Processed text file: case_030.txt
# 2025-06-22 20:08:38,252 - Extracted nomor_perkara: 323 k pdt sus pailit 2025 for case_031.txt
# 2025-06-22 20:08:38,254 - Extracted metadata from case_031.txt
# 2025-06-22 20:08:38,255 - Processed text file: case_031.txt
# 2025-06-22 20:08:38,257 - Extracted nomor_perkara: 344 k pdt sus pailit 2025 for case_032.txt
# 2025-06-22 20:08:38,260 - Extracted metadata from case_032.txt
# 2025-06-22 20:08:38,261 - Processed text file: case_032.txt
# 2025-06-22 20:08:38,263 - Extracted nomor_perkara: 36 k pdt sus pailit 2025 for case_033.txt
# 2025-06-22 20:08:38,265 - Extracted metadata from case_033.txt
# 2025-06-22 20:08:38,266 - Processed text file: case_033.txt
# 2025-06-22 20:08:38,267 - Extracted nomor_perkara: 370 k pdt sus pailit 2025 for case_034.txt
# 2025-06-22 20:08:38,269 - Extracted metadata from case_034.txt
# 2025-06-22 20:08:38,270 - Processed text file: case_034.txt
# 2025-06-22 20:08:38,271 - Extracted nomor_perkara: 38 k pdt sus pailit 2025 for case_035.txt
# 2025-06-22 20:08:38,274 - Extracted metadata from case_035.txt
# 2025-06-22 20:08:38,275 - Processed text file: case_035.txt
# 2025-06-22 20:08:38,276 - No nomor_perkara found in case_036.txt
# 2025-06-22 20:08:38,277 - Extracted nomor_perkara:  for case_036.txt
# 2025-06-22 20:08:38,280 - No hakim_ketua found in case_036.txt
# 2025-06-22 20:08:38,282 - Extracted metadata from case_036.txt
# 2025-06-22 20:08:38,283 - Processed text file: case_036.txt
# 2025-06-22 20:08:38,284 - Extracted nomor_perkara: 3 pk pdt sus pailit 2025 for case_037.txt
# 2025-06-22 20:08:38,287 - Extracted metadata from case_037.txt
# 2025-06-22 20:08:38,288 - Processed text file: case_037.txt
# 2025-06-22 20:08:38,289 - Extracted nomor_perkara: 40 k pdt sus pailit 2025 for case_038.txt
# 2025-06-22 20:08:38,291 - Extracted metadata from case_038.txt
# 2025-06-22 20:08:38,293 - Processed text file: case_038.txt
# 2025-06-22 20:08:38,294 - Extracted nomor_perkara: 417 k pdt sus pailit 2025 for case_039.txt
# 2025-06-22 20:08:38,297 - Extracted metadata from case_039.txt
# 2025-06-22 20:08:38,298 - Processed text file: case_039.txt
# 2025-06-22 20:08:38,299 - Extracted nomor_perkara: 418 k pdt sus pailit 2025 for case_040.txt
# 2025-06-22 20:08:38,301 - Extracted metadata from case_040.txt
# 2025-06-22 20:08:38,302 - Processed text file: case_040.txt
# 2025-06-22 20:08:38,303 - Extracted nomor_perkara: 420 k pdt sus pailit 2025 for case_041.txt
# 2025-06-22 20:08:38,304 - Extracted metadata from case_041.txt
# 2025-06-22 20:08:38,306 - Processed text file: case_041.txt
# 2025-06-22 20:08:38,306 - Extracted nomor_perkara: 44 k pdt sus pailit 2025 for case_042.txt
# 2025-06-22 20:08:38,310 - Extracted metadata from case_042.txt
# 2025-06-22 20:08:38,313 - Processed text file: case_042.txt
# 2025-06-22 20:08:38,314 - Extracted nomor_perkara: 45 k pdt sus pailit 2025 for case_043.txt
# 2025-06-22 20:08:38,316 - Extracted metadata from case_043.txt
# 2025-06-22 20:08:38,317 - Processed text file: case_043.txt
# 2025-06-22 20:08:38,318 - Extracted nomor_perkara: 49 k pdt sus pailit 2025 for case_044.txt
# 2025-06-22 20:08:38,319 - Extracted metadata from case_044.txt
# 2025-06-22 20:08:38,320 - Processed text file: case_044.txt
# 2025-06-22 20:08:38,322 - Extracted nomor_perkara: 4 pk pdt sus pailit 2025 for case_045.txt
# 2025-06-22 20:08:38,323 - Extracted metadata from case_045.txt
# 2025-06-22 20:08:38,324 - Processed text file: case_045.txt
# 2025-06-22 20:08:38,326 - Extracted nomor_perkara: 573 k pdt sus pailit 2024 for case_046.txt
# 2025-06-22 20:08:38,328 - Extracted metadata from case_046.txt
# 2025-06-22 20:08:38,329 - Processed text file: case_046.txt
# 2025-06-22 20:08:38,331 - Extracted nomor_perkara: 575 k pdt sus pailit 2024 for case_047.txt
# 2025-06-22 20:08:38,333 - Extracted metadata from case_047.txt
# 2025-06-22 20:08:38,335 - Processed text file: case_047.txt
# 2025-06-22 20:08:38,336 - Extracted nomor_perkara: 5 k pdt sus pailit 2025 for case_048.txt
# 2025-06-22 20:08:38,337 - Extracted metadata from case_048.txt
# 2025-06-22 20:08:38,339 - Processed text file: case_048.txt
# 2025-06-22 20:08:38,340 - Extracted nomor_perkara: 603 k pdt sus pailit 2024 for case_049.txt
# 2025-06-22 20:08:38,342 - Extracted metadata from case_049.txt
# 2025-06-22 20:08:38,342 - Processed text file: case_049.txt
# 2025-06-22 20:08:38,343 - Extracted nomor_perkara: 606 k pdt sus pailit 2024 for case_050.txt
# 2025-06-22 20:08:38,346 - Extracted metadata from case_050.txt
# 2025-06-22 20:08:38,347 - Processed text file: case_050.txt
# 2025-06-22 20:08:38,348 - Extracted nomor_perkara: 63 pk pdt sus pailit 2024 for case_051.txt
# 2025-06-22 20:08:38,350 - Extracted metadata from case_051.txt
# 2025-06-22 20:08:38,351 - Processed text file: case_051.txt
# 2025-06-22 20:08:38,352 - Extracted nomor_perkara: 1473 k pdt sus pailit 2021 for case_052.txt
# 2025-06-22 20:08:38,355 - Extracted metadata from case_052.txt
# 2025-06-22 20:08:38,355 - Processed text file: case_052.txt
# 2025-06-22 20:08:38,357 - Extracted nomor_perkara: 65 k pdt sus pailit 2025 for case_053.txt
# 2025-06-22 20:08:38,358 - Extracted metadata from case_053.txt
# 2025-06-22 20:08:38,359 - Processed text file: case_053.txt
# 2025-06-22 20:08:38,360 - Extracted nomor_perkara: 66 k pdt sus pailit 2025 for case_054.txt
# 2025-06-22 20:08:38,362 - Extracted metadata from case_054.txt
# 2025-06-22 20:08:38,363 - Processed text file: case_054.txt
# 2025-06-22 20:08:38,364 - Extracted nomor_perkara: 70 pk pdt sus pailit 2024 for case_055.txt
# 2025-06-22 20:08:38,365 - No ringkasan_fakta found in case_055.txt. Sample text: inistrasi peninjauan kembali rp 9 980 000 00 jumlah rp10 000 000 00 untuk salinan mahkamah agung ri an panitera panitera muda perdata khusus h ahmad ardianda patria s h m hum nip 19621220 198612 1 001
# 2025-06-22 20:08:38,366 - Extracted metadata from case_055.txt
# 2025-06-22 20:08:38,367 - Processed text file: case_055.txt
# 2025-06-22 20:08:38,368 - Extracted nomor_perkara: 776 k pdt sus pailit 2024 for case_056.txt
# 2025-06-22 20:08:38,370 - Extracted metadata from case_056.txt
# 2025-06-22 20:08:38,370 - Processed text file: case_056.txt
# 2025-06-22 20:08:38,372 - Extracted nomor_perkara: 777 k pdt sus pailit 2024 for case_057.txt
# 2025-06-22 20:08:38,374 - Extracted metadata from case_057.txt
# 2025-06-22 20:08:38,375 - Processed text file: case_057.txt
# 2025-06-22 20:08:38,376 - Extracted nomor_perkara: 81 k pdt sus pailit 2025 for case_058.txt
# 2025-06-22 20:08:38,377 - Extracted metadata from case_058.txt
# 2025-06-22 20:08:38,379 - Processed text file: case_058.txt
# 2025-06-22 20:08:38,380 - Extracted nomor_perkara: 846 k pdt sus pailit 2024 for case_059.txt
# 2025-06-22 20:08:38,381 - Extracted metadata from case_059.txt
# 2025-06-22 20:08:38,382 - Processed text file: case_059.txt
# 2025-06-22 20:08:38,384 - Extracted nomor_perkara: 9 pk pdt sus pailit 2025 for case_060.txt
# 2025-06-22 20:08:38,385 - Extracted metadata from case_060.txt
# 2025-06-22 20:08:38,386 - Processed text file: case_060.txt
# 2025-06-22 20:08:38,389 - Saved metadata to d:\AL FITRA\STUDI UMM\SEMESTER 6\TEORI\PENALARAN KOMPUTER\SOURCE CODE\PENALARAN KOMPUTER\COMPUTER_REASONING_CBR\CBR\data\processed\cases.csv
# 2025-06-22 20:08:38,389 - Processed 60 files and saved to d:\AL FITRA\STUDI UMM\SEMESTER 6\TEORI\PENALARAN KOMPUTER\SOURCE CODE\PENALARAN KOMPUTER\COMPUTER_REASONING_CBR\CBR\data\processed\cases.csv
